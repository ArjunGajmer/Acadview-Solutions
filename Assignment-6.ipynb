# %% [markdown]
# # Solutions to Assignment 6
#
# ### Download the weather dataset
# 	https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv
#
# ### Plot atleast 10 visualization for the same dataset with different data points. Ensure that the type of visualization is appropriate.

# %%
##Import the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
##Extract csv
df = pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv ")

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
##Drop null values
df = df.dropna()

# %% [markdown]
# #### Examples of Univariate Plots
# Plotted below are some univariate graphs. Feel free to add your own graphs.

# %%
##Example 1
sns.distplot(df['Rainfall'], bins= 20)

# %%
##Example 2
sns.kdeplot(df['Sunshine'], shade=True)

# %%
##Example 3
sns.distplot(df['WindGustSpeed'], hist=False)

# %%
##Example 4
sns.countplot(df['RainToday'])

# %%
##Example 5
sns.boxplot(df['MaxTemp'])

# %% [markdown]
# #### Examples of Bivariate Plots
#
# Plotted below are some bivariate graphs. Feel free to add your own graphs.

# %%
##Example 1
sns.jointplot(x='Sunshine', y='Evaporation', data=df)

# %%
##Example 2
sns.jointplot(x=df['Temp9am'], y=df['Humidity9am'], color='k', kind="hex")

# %%
##Example 3
sns.jointplot(x=df['Cloud3pm'], y=df['WindSpeed3pm'], kind="kde")
